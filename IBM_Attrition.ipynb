# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(df["Attrition"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# ...

# %%
#removing meaningless columns
df=df.drop('EmployeeCount',axis=1)
df=df.drop('StandardHours',axis=1)

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
#transforming non-numerical to numerical col
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column in df.columns:
    if df[column].dtype== np.number:
        continue
    df[column]=le.fit_transform(df[column])
# Out:
# <ipython-input-16-c151921e8f7b>:5: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype== np.number:

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      23          1               2        624           2                 0
# 1      31          0               1        113           1                 7
# 2      19          1               2        805           1                 1
# 3      15          0               1        820           1                 2
# 4       9          0               2        312           1                 1
# ...   ...        ...             ...        ...         ...               ...
# 1465   18          0               1        494           1                22
# 1466   21          0               2        327           1                 5
# 1467    9          0               2         39           1                 3
# 1468   31          0               1        579           2                 1
# 1469   16          0               2        336           1                 7
#
# ...

# %%
df
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0             1               2        624           2                 0
# 1             0               1        113           1                 7
# 2             1               2        805           1                 1
# 3             0               1        820           1                 2
# 4             0               2        312           1                 1
# ...         ...             ...        ...         ...               ...
# 1465          0               1        494           1                22
# 1466          0               2        327           1                 5
# 1467          0               2         39           1                 3
# 1468          0               1        579           2                 1
# 1469          0               2        336           1                 7
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %%
df.describe()
# Out:
#          Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000     1470.000000  1470.000000  1470.000000
# mean      0.161224        1.607483   443.074830     1.260544
# std       0.367863        0.665455   253.513199     0.527792
# min       0.000000        0.000000     0.000000     0.000000
# 25%       0.000000        1.000000   225.000000     1.000000
# 50%       0.000000        2.000000   447.000000     1.000000
# 75%       0.000000        2.000000   660.000000     2.000000
# max       1.000000        2.000000   885.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeNumber  \
# count       1470.000000  1470.000000     1470.000000     1470.000000
# mean           8.192517     1.912925        2.247619      734.500000
# std            8.106864     1.024165        1.331369      424.496761
# min            0.000000     0.000000        0.000000        0.000000
# ...

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # A breakdown of distance from home by job role and attrition.

# %%
distancefrhome_JobRole_attrition = df[["DistanceFromHome", "Attrition", "JobRole"]]
distancefrhome_JobRole_attrition=distancefrhome_JobRole_attrition .replace({"JobROLE": {1:'Healthcare Representative',2:'Human Resources',3:'Laboratory Technician',4:'Manager',5:'Manufacturing Director',6:'Research Director',7:'Research Scientist',8:'Sales Executive',9:'Sales Representative'}})
distancefrhome_JobRole_attrition= distancefrhome_JobRole_attrition.groupby(["JobRole", "Attrition"]).agg('mean')
print(distancefrhome_JobRole_attrition)
distancefrhome_JobRole_attrition.unstack(level=-1)['DistanceFromHome'].plot(kind='bar')
# Out:
#                    DistanceFromHome
# JobRole Attrition
# 0       0                  8.204918
#         1                 16.666667
# 1       0                  5.600000
#         1                 12.416667
# 2       0                  8.329949
#         1                  8.661290
# 3       0                  6.927835
#         1                  9.000000
# 4       0                  8.533333
#         1                  7.800000
# 5       0                  7.474359
#         1                  6.000000
# 6       0                  7.869388
#         1                  8.765957
# 7       0                  8.026022
#         1                 11.649123
# 8       0                  8.000000
#         1                  7.151515
# <AxesSubplot:xlabel='JobRole'>

# %% [markdown]
# # average monthly income by education and attrition

# %%
edu_attrition_income = df[["Education", "Attrition", "MonthlyIncome"]]
edu_attrition_income = edu_attrition_income.groupby(["Education", "Attrition"]).agg('mean')
print(edu_attrition_income)
edu_attrition_income.unstack(level=-1)['MonthlyIncome'].plot(kind='bar')
# Out:
#                      MonthlyIncome
# Education Attrition
# 0         0             587.928058
#           1             413.354839
# 1         0             675.281513
#           1             459.727273
# 2         0             683.293869
#           1             451.929293
# 3         0             726.567647
#           1             567.017241
# 4         0             841.651163
#           1             672.400000
# <AxesSubplot:xlabel='Education'>
